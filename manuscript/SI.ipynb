# %% [markdown]
# # Supplemental Information Tables + Figures

# %%
import sys 
sys.path.append("..")
from retire import Retire

# %%
retire = Retire()

# %%
retire.get_explanations()
# Out:
#                              Name                   Match Scores  \
# 0                     Dolet Hills             {4: 0.94, 5: 0.06}
# 1     Martin Drake // South Plant                       {7: 1.0}
# 2                     E D Edwards                       {6: 1.0}
# 3            Lowman Energy Center                       {0: 1.0}
# 4                        Waukegan                       {4: 1.0}
# 5                       Escalante                       {4: 1.0}
# 6                     Will County             {5: 0.07, 6: 0.93}
# 7                       Oklaunion             {3: 0.95, 5: 0.05}
# 8                     Joppa Steam           {2: 0.915, 6: 0.085}
# 9              Bridgeport Station                       {0: 1.0}
# 10     Crawfordsville Power Plant                       {6: 1.0}
# 11                C D McIntosh Jr             {0: 0.98, 1: 0.02}
# 12                        Lansing  {2: 0.095, 5: 0.07, 4: 0.835}
# ...

# %%
retire.get_group_report()
# Out:
#    Group                               Name Number of Plants  \
# 0      0                  Fuel Blend Plants               39
# 1      1  Retrofitted but Vulnerable Plants                3
# 2      2         Democratic Majority Plants               14
# 3      3          High Health Impact Plants               29
# 4      4                   Expensive Plants               74
# 5      5                       Young Plants               11
# 6      6        Plants in Anti-Coal Regions               14
# 7      7              Air Quality Offenders                6
# 8     -1                        Unclustered        8.3.14.50
#
#    Percent of Capacity  Percent with Planned Retirement  \
# 0                17.05                            45.30
# 1                 3.93                            19.13
# 2                 5.07                            78.57
# 3                28.81                            50.26
# 4                29.18                            25.78
# ...
